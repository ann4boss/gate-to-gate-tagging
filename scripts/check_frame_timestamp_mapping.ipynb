# %% [markdown]
# ## Check Frame and Timestamp mapping

# %%
import json
import cv2

run_id = "Aerni_SUI_Lauf1_20251116_SL_Levi"

with open(f"../data/annotations/{run_id}.json") as f:
    annot = json.load(f)

# Check gate 5
gate5 = annot["gates"][5]
print(f"Gate 5 → frame {gate5['frame']} at {gate5['position_s']}s")

# Load and show that frame
frame_path = f"../data/frames/{run_id}/{gate5['frame']:06d}.jpg"
img = cv2.imread(frame_path)
cv2.imwrite("../checks/check_gate5.jpg", img)  # save it so you can just open it
# Out:
# Gate 5 → frame 295 at 9.833s
# True
